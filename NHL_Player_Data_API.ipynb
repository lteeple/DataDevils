# %%
import json

# recursively iterate through values in dict to retrieve data for wins_df
def get_first_value(value):
    if isinstance(value, dict):
        for v in value.values():
            if isinstance(v, (dict, list)):
                return get_first_value(v)
            else:
                return v
        # Recursively call get_first_value if the value is a dictionary
        return get_first_value(value)
    else:
        # Return the value if it's not a dictionary
        return value

# %%
import requests
import pandas as pd

# API call to retrieve current top goal scorer data
url = "https://api-web.nhle.com/v1/skater-stats-leaders/current"
params = {
    "categories": "goals",
    "limit": 5
}
response = requests.get(url, params=params)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Extract the JSON data from the response
    data = response.json()
    
    # Create an empty list to store column names
    player_data_col_names= []
    # Get the names of all the columns
    for col in data['goals'][0]: 
        player_data_col_names.append(col)

    # Df to show all win stats
    goals_df = pd.DataFrame(columns=player_data_col_names)
    
    # Loop through items in dict, retrieve data by keys "cat"
    for player_stat in data['goals']:
        player = {}
        for cat in player_data_col_names:
            player[cat] = get_first_value(player_stat.get(cat, None))
            
        goals_df.loc[len(goals_df)] = player

    print(goals_df)

    # Check df shape
    num_columns = goals_df.shape[1]
    print("Number of columns:", num_columns)
    print("Number of rows:", len(goals_df))

else:
    print("Failed to fetch data from the API:", response.status_code)
# Out:
#         id firstName   lastName  sweaterNumber  \
# 0  8479318    Auston   Matthews             34
# 1  8477933       Sam   Reinhart             13
# 2  8475786      Zach      Hyman             18
# 3  8477956     David   Pastrnak             88
# 4  8477492    Nathan  MacKinnon             29
#
#                                             headshot teamAbbrev     teamName  \
# 0  https://assets.nhle.com/mugs/nhl/20232024/TOR/...        TOR  Maple Leafs
# 1  https://assets.nhle.com/mugs/nhl/20232024/FLA/...        FLA     Panthers
# 2  https://assets.nhle.com/mugs/nhl/20232024/EDM/...        EDM       Oilers
# 3  https://assets.nhle.com/mugs/nhl/20232024/BOS/...        BOS       Bruins
# 4  https://assets.nhle.com/mugs/nhl/20232024/COL/...        COL    Avalanche
#
#                                             teamLogo position  value
# 0  https://assets.nhle.com/logos/nhl/svg/TOR_ligh...        C     54
# 1  https://assets.nhle.com/logos/nhl/svg/FLA_ligh...        C     45
# 2  https://assets.nhle.com/logos/nhl/svg/EDM_ligh...        L     43
# 3  https://assets.nhle.com/logos/nhl/svg/BOS_ligh...        R     41
# 4  https://assets.nhle.com/logos/nhl/svg/COL_ligh...        C     40
# Number of columns: 10

# %%
import requests
import pandas as pd
# API call to retrieve current top goal scorer data
url = "https://api-web.nhle.com/v1/goalie-stats-leaders/current"
params = {
    "categories": "wins",
    "limit": 50
}
response = requests.get(url, params=params)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Extract the JSON data from the response
    data = response.json()

    # Create an empty list to store column names
    player_data_col_names= []
    # Get the names of all the columns
    for col in data['wins'][0]: 
        player_data_col_names.append(col)

    # Df to show all win stats
    wins_df = pd.DataFrame(columns=player_data_col_names)
    
    # Loop through items in dict, retrieve data by keys "cat"
    for player_stat in data['wins']:
        player = {}
        for cat in player_data_col_names:
            player[cat] = get_first_value(player_stat.get(cat, None))
            
        wins_df.loc[len(wins_df)] = player

    print(wins_df)

    # Check df shape
    num_columns = wins_df.shape[1]
    print("Number of columns:", num_columns)
    print("Number of rows:", len(wins_df))

else:
    print("Failed to fetch data from the API:", response.status_code)
# Out:
#          id   firstName      lastName  sweaterNumber  \
# 0   8477967    Thatcher         Demko             35
# 1   8480382   Alexandar      Georgiev             40
# 2   8475683      Sergei     Bobrovsky             72
# 3   8476945      Connor    Hellebuyck             37
# 4   8479973      Stuart       Skinner             74
# 5   8477424       Juuse         Saros             74
# 6   8478048        Igor    Shesterkin             31
# 7   8479979        Jake     Oettinger             29
# 8   8478009        Ilya       Sorokin             30
# 9   8476412      Jordan    Binnington             50
# 10  8474593       Jacob     Markstrom             25
# 11  8476883      Andrei   Vasilevskiy             88
# 12  8480280      Jeremy       Swayman              1
# 13  8480045  Ukko-Pekka     Luukkonen              1
# 14  8475660         Cam        Talbot             39
# 15  8481035      Samuel        Ersson             33
# 16  8477465     Tristan         Jarry             35
# 17  8478971      Connor        Ingram             39
# 18  8479312        Alex          Lyon             34
# 19  8478916        Joey       Daccord             35
# 20  8476999       Linus       Ullmark             35
# 21  8478492        Ilya      Samsonov             35
# 22  8480313       Logan      Thompson             36
# 23  8479406       Filip    Gustavsson             32
# 24  8481611       Pyotr     Kochetkov             52
# 25  8477970       Vitek       Vanecek             41
# 26  8478499        Adin          Hill             33
# 27  8479292     Charlie      Lindgren             79
# 28  8475809       Scott     Wedgewood             41
# 29  8470594  Marc-Andre        Fleury             29
# 30  8471734    Jonathan         Quick             32
# 31  8478470         Sam  Montembeault             35
# 32  8475852        Petr        Mrazek             34
# 33  8476914      Joonas     Korpisalo             70
# 34  8475311       Darcy       Kuemper             35
# 35  8476434        John        Gibson             36
# 36  8476932     Anthony       Stolarz             41
# 37  8478007       Elvis    Merzlikins             90
# 38  8479394      Carter          Hart             79
# 39  8477293       Antti        Raanta             32
# 40  8477992       Jonas     Johansson             31
# 41  8476316     Laurent      Brossoit             39
# 42  8474889      Martin         Jones             31
# 43  8480981        Joel         Hofer             30
# 44  8476341       Anton      Forsberg             31
# 45  8479496       David       Rittich             31
# 46  8480843       Lukas        Dostal              1
# 47  8475831     Philipp      Grubauer             31
# 48  8477968        Alex   Nedeljkovic             39
# 49  8478406   Mackenzie     Blackwood             29
#
#                                              headshot teamAbbrev  \
# 0   https://assets.nhle.com/mugs/nhl/20232024/VAN/...        VAN
# 1   https://assets.nhle.com/mugs/nhl/20232024/COL/...        COL
# 2   https://assets.nhle.com/mugs/nhl/20232024/FLA/...        FLA
# 3   https://assets.nhle.com/mugs/nhl/20232024/WPG/...        WPG
# 4   https://assets.nhle.com/mugs/nhl/20232024/EDM/...        EDM
# 5   https://assets.nhle.com/mugs/nhl/20232024/NSH/...        NSH
# 6   https://assets.nhle.com/mugs/nhl/20232024/NYR/...        NYR
# 7   https://assets.nhle.com/mugs/nhl/20232024/DAL/...        DAL
# 8   https://assets.nhle.com/mugs/nhl/20232024/NYI/...        NYI
# 9   https://assets.nhle.com/mugs/nhl/20232024/STL/...        STL
# 10  https://assets.nhle.com/mugs/nhl/20232024/CGY/...        CGY
# 11  https://assets.nhle.com/mugs/nhl/20232024/TBL/...        TBL
# 12  https://assets.nhle.com/mugs/nhl/20232024/BOS/...        BOS
# 13  https://assets.nhle.com/mugs/nhl/20232024/BUF/...        BUF
# 14  https://assets.nhle.com/mugs/nhl/20232024/LAK/...        LAK
# 15  https://assets.nhle.com/mugs/nhl/20232024/PHI/...        PHI
# 16  https://assets.nhle.com/mugs/nhl/20232024/PIT/...        PIT
# 17  https://assets.nhle.com/mugs/nhl/20232024/ARI/...        ARI
# 18  https://assets.nhle.com/mugs/nhl/20232024/DET/...        DET
# 19  https://assets.nhle.com/mugs/nhl/20232024/SEA/...        SEA
# 20  https://assets.nhle.com/mugs/nhl/20232024/BOS/...        BOS
# 21  https://assets.nhle.com/mugs/nhl/20232024/TOR/...        TOR
# 22  https://assets.nhle.com/mugs/nhl/20232024/VGK/...        VGK
# 23  https://assets.nhle.com/mugs/nhl/20232024/MIN/...        MIN
# 24  https://assets.nhle.com/mugs/nhl/20232024/CAR/...        CAR
# 25  https://assets.nhle.com/mugs/nhl/20232024/NJD/...        NJD
# 26  https://assets.nhle.com/mugs/nhl/20232024/VGK/...        VGK
# 27  https://assets.nhle.com/mugs/nhl/20232024/WSH/...        WSH
# 28  https://assets.nhle.com/mugs/nhl/20232024/DAL/...        DAL
# 29  https://assets.nhle.com/mugs/nhl/20232024/MIN/...        MIN
# 30  https://assets.nhle.com/mugs/nhl/20232024/NYR/...        NYR
# 31  https://assets.nhle.com/mugs/nhl/20232024/MTL/...        MTL
# 32  https://assets.nhle.com/mugs/nhl/20232024/CHI/...        CHI
# 33  https://assets.nhle.com/mugs/nhl/20232024/OTT/...        OTT
# 34  https://assets.nhle.com/mugs/nhl/20232024/WSH/...        WSH
# 35  https://assets.nhle.com/mugs/nhl/20232024/ANA/...        ANA
# 36  https://assets.nhle.com/mugs/nhl/20232024/FLA/...        FLA
# 37  https://assets.nhle.com/mugs/nhl/20232024/CBJ/...        CBJ
# 38  https://assets.nhle.com/mugs/nhl/20232024/PHI/...        PHI
# 39  https://assets.nhle.com/mugs/nhl/20232024/CAR/...        CAR
# 40  https://assets.nhle.com/mugs/nhl/20232024/TBL/...        TBL
# 41  https://assets.nhle.com/mugs/nhl/20232024/WPG/...        WPG
# 42  https://assets.nhle.com/mugs/nhl/20232024/TOR/...        TOR
# 43  https://assets.nhle.com/mugs/nhl/20232024/STL/...        STL
# 44  https://assets.nhle.com/mugs/nhl/20232024/OTT/...        OTT
# 45  https://assets.nhle.com/mugs/nhl/20232024/LAK/...        LAK
# 46  https://assets.nhle.com/mugs/nhl/20232024/ANA/...        ANA
# 47  https://assets.nhle.com/mugs/nhl/20232024/SEA/...        SEA
# 48  https://assets.nhle.com/mugs/nhl/20232024/PIT/...        PIT
# 49  https://assets.nhle.com/mugs/nhl/20232024/SJS/...        SJS
#
#           teamName                                           teamLogo  \
# 0          Canucks  https://assets.nhle.com/logos/nhl/svg/VAN_ligh...
# 1        Avalanche  https://assets.nhle.com/logos/nhl/svg/COL_ligh...
# 2         Panthers  https://assets.nhle.com/logos/nhl/svg/FLA_ligh...
# 3             Jets  https://assets.nhle.com/logos/nhl/svg/WPG_ligh...
# 4           Oilers  https://assets.nhle.com/logos/nhl/svg/EDM_ligh...
# 5        Predators  https://assets.nhle.com/logos/nhl/svg/NSH_ligh...
# 6          Rangers  https://assets.nhle.com/logos/nhl/svg/NYR_ligh...
# 7            Stars  https://assets.nhle.com/logos/nhl/svg/DAL_ligh...
# 8        Islanders  https://assets.nhle.com/logos/nhl/svg/NYI_ligh...
# 9            Blues  https://assets.nhle.com/logos/nhl/svg/STL_ligh...
# 10          Flames  https://assets.nhle.com/logos/nhl/svg/CGY_ligh...
# 11       Lightning  https://assets.nhle.com/logos/nhl/svg/TBL_ligh...
# 12          Bruins  https://assets.nhle.com/logos/nhl/svg/BOS_ligh...
# 13          Sabres  https://assets.nhle.com/logos/nhl/svg/BUF_ligh...
# 14           Kings  https://assets.nhle.com/logos/nhl/svg/LAK_ligh...
# 15          Flyers  https://assets.nhle.com/logos/nhl/svg/PHI_ligh...
# 16        Penguins  https://assets.nhle.com/logos/nhl/svg/PIT_ligh...
# 17         Coyotes  https://assets.nhle.com/logos/nhl/svg/ARI_ligh...
# 18       Red Wings  https://assets.nhle.com/logos/nhl/svg/DET_ligh...
# 19          Kraken  https://assets.nhle.com/logos/nhl/svg/SEA_ligh...
# 20          Bruins  https://assets.nhle.com/logos/nhl/svg/BOS_ligh...
# 21     Maple Leafs  https://assets.nhle.com/logos/nhl/svg/TOR_ligh...
# 22  Golden Knights  https://assets.nhle.com/logos/nhl/svg/VGK_ligh...
# 23            Wild  https://assets.nhle.com/logos/nhl/svg/MIN_ligh...
# 24      Hurricanes  https://assets.nhle.com/logos/nhl/svg/CAR_ligh...
# 25          Devils  https://assets.nhle.com/logos/nhl/svg/NJD_ligh...
# 26  Golden Knights  https://assets.nhle.com/logos/nhl/svg/VGK_ligh...
# 27        Capitals  https://assets.nhle.com/logos/nhl/svg/WSH_ligh...
# 28           Stars  https://assets.nhle.com/logos/nhl/svg/DAL_ligh...
# 29            Wild  https://assets.nhle.com/logos/nhl/svg/MIN_ligh...
# 30         Rangers  https://assets.nhle.com/logos/nhl/svg/NYR_ligh...
# 31       Canadiens  https://assets.nhle.com/logos/nhl/svg/MTL_ligh...
# 32      Blackhawks  https://assets.nhle.com/logos/nhl/svg/CHI_ligh...
# 33        Senators  https://assets.nhle.com/logos/nhl/svg/OTT_ligh...
# 34        Capitals  https://assets.nhle.com/logos/nhl/svg/WSH_ligh...
# 35           Ducks  https://assets.nhle.com/logos/nhl/svg/ANA_ligh...
# 36        Panthers  https://assets.nhle.com/logos/nhl/svg/FLA_ligh...
# 37    Blue Jackets  https://assets.nhle.com/logos/nhl/svg/CBJ_ligh...
# 38          Flyers  https://assets.nhle.com/logos/nhl/svg/PHI_ligh...
# 39      Hurricanes  https://assets.nhle.com/logos/nhl/svg/CAR_ligh...
# 40       Lightning  https://assets.nhle.com/logos/nhl/svg/TBL_ligh...
# 41            Jets  https://assets.nhle.com/logos/nhl/svg/WPG_ligh...
# 42     Maple Leafs  https://assets.nhle.com/logos/nhl/svg/TOR_ligh...
# 43           Blues  https://assets.nhle.com/logos/nhl/svg/STL_ligh...
# 44        Senators  https://assets.nhle.com/logos/nhl/svg/OTT_ligh...
# 45           Kings  https://assets.nhle.com/logos/nhl/svg/LAK_ligh...
# 46           Ducks  https://assets.nhle.com/logos/nhl/svg/ANA_ligh...
# 47          Kraken  https://assets.nhle.com/logos/nhl/svg/SEA_ligh...
# 48        Penguins  https://assets.nhle.com/logos/nhl/svg/PIT_ligh...
# 49          Sharks  https://assets.nhle.com/logos/nhl/svg/SJS_ligh...
#
#    position  value
# 0         G     34
# 1         G     33
# 2         G     31
# 3         G     30
# 4         G     29
# 5         G     27
# 6         G     27
# 7         G     25
# 8         G     22
# 9         G     22
# 10        G     22
# 11        G     22
# 12        G     21
# 13        G     20
# 14        G     19
# 15        G     18
# 16        G     18
# 17        G     18
# 18        G     18
# 19        G     17
# 20        G     17
# 21        G     17
# 22        G     17
# 23        G     17
# 24        G     17
# 25        G     17
# 26        G     16
# 27        G     15
# 28        G     14
# 29        G     14
# 30        G     14
# 31        G     13
# 32        G     13
# 33        G     13
# 34        G     13
# 35        G     13
# 36        G     13
# 37        G     12
# 38        G     12
# 39        G     12
# 40        G     11
# 41        G     11
# 42        G     11
# 43        G     11
# 44        G     11
# 45        G     10
# 46        G     10
# 47        G     10
# 48        G      9
# 49        G      9
# Number of columns: 10

# %%
import requests
import pandas as pd
# API call to retrieve current top goal scorer data
url = "https://api-web.nhle.com/v1/standings/now"
params = {
    "categories": "standings",
    "limit": 32
}
response = requests.get(url, params=params)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Extract the JSON data from the response
    data = response.json()

    # Create an empty list to store column names
    player_data_col_names= []
    # Get the names of all the columns
    for col in data['standings'][0]: 
        player_data_col_names.append(col)

    # Df to show all win stats
    standings_df = pd.DataFrame(columns=player_data_col_names)
    
    # Loop through items in dict, retrieve data by keys "cat"
    for player_stat in data['standings']:
        player = {}
        for cat in player_data_col_names:
            player[cat] = get_first_value(player_stat.get(cat, None))
            
        standings_df.loc[len(standings_df)] = player

    print(standings_df)

    # Check df shape
    num_columns = standings_df.shape[1]
    print("Number of columns:", num_columns)
    print("Number of rows:", len(standings_df))

else:
    print("Failed to fetch data from the API:", response.status_code)
# Out:
#    conferenceAbbrev  conferenceHomeSequence  conferenceL10Sequence  \
# 0                 E                       4                      1
# 1                 W                       3                      9
# 2                 E                       1                      8
# 3                 W                       5                      6
# 4                 E                       2                      3
# 5                 W                       2                      3
# 6                 W                       1                      2
# 7                 E                       3                      2
# 8                 E                       9                      5
# 9                 W                       4                      5
# 10                W                       8                      1
# 11                W                      10                     10
# 12                W                       6                     13
# 13                E                       5                     12
# 14                E                      12                     11
# 15                E                       6                     10
# 16                E                       8                      4
# 17                E                       7                      6
# 18                W                       7                     12
# 19                W                       9                      8
# 20                W                      12                      4
# 21                W                      11                      7
# 22                E                      13                     14
# 23                E                      14                      7
# 24                E                      10                     13
# 25                E                      16                     15
# 26                W                      13                     14
# 27                E                      11                     16
# 28                E                      15                      9
# 29                W                      16                     11
# 30                W                      15                     16
# 31                W                      14                     15
#
#    conferenceName  conferenceRoadSequence  conferenceSequence        date  \
# 0         Eastern                       1                   1  2024-03-12
# 1         Western                       2                   1  2024-03-12
# 2         Eastern                       3                   2  2024-03-12
# 3         Western                       1                   2  2024-03-12
# 4         Eastern                       4                   3  2024-03-12
# 5         Western                       5                   3  2024-03-12
# 6         Western                      11                   4  2024-03-12
# 7         Eastern                       6                   4  2024-03-12
# 8         Eastern                       2                   5  2024-03-12
# 9         Western                       6                   5  2024-03-12
# 10        Western                       4                   6  2024-03-12
# 11        Western                       3                   7  2024-03-12
# 12        Western                       9                   8  2024-03-12
# 13        Eastern                      13                   6  2024-03-12
# 14        Eastern                       5                   7  2024-03-12
# 15        Eastern                      10                   8  2024-03-12
# 16        Eastern                       9                   9  2024-03-12
# 17        Eastern                      12                  10  2024-03-12
# 18        Western                      12                   9  2024-03-12
# 19        Western                      10                  10  2024-03-12
# 20        Western                       7                  11  2024-03-12
# 21        Western                       8                  12  2024-03-12
# 22        Eastern                       7                  11  2024-03-12
# 23        Eastern                       8                  12  2024-03-12
# 24        Eastern                      14                  13  2024-03-12
# 25        Eastern                      11                  14  2024-03-12
# 26        Western                      14                  13  2024-03-12
# 27        Eastern                      16                  15  2024-03-12
# 28        Eastern                      15                  16  2024-03-12
# 29        Western                      13                  14  2024-03-12
# 30        Western                      15                  15  2024-03-12
# 31        Western                      16                  16  2024-03-12
#
#    divisionAbbrev  divisionHomeSequence  divisionL10Sequence  ... streakCount  \
# 0               A                     2                    1  ...           1
# 1               P                     1                    4  ...           4
# 2               A                     1                    4  ...           1
# 3               C                     3                    4  ...           5
# 4               M                     1                    2  ...           2
# 5               C                     2                    3  ...           1
# 6               C                     1                    2  ...           3
# 7               M                     2                    1  ...           3
# 8               A                     5                    2  ...           1
# 9               P                     2                    2  ...           1
# 10              C                     5                    1  ...           1
# 11              P                     4                    5  ...           1
# 12              P                     3                    7  ...           1
# 13              A                     3                    6  ...           1
# 14              M                     6                    6  ...           1
# 15              A                     4                    5  ...           5
# 16              M                     4                    3  ...           1
# 17              M                     3                    4  ...           1
# 18              C                     4                    6  ...           1
# 19              C                     6                    5  ...           1
# 20              P                     6                    1  ...           1
# 21              P                     5                    3  ...           2
# 22              M                     7                    8  ...           2
# 23              A                     7                    3  ...           1
# 24              M                     5                    7  ...           3
# 25              A                     8                    7  ...           2
# 26              C                     7                    7  ...           1
# 27              A                     6                    8  ...           1
# 28              M                     8                    5  ...           1
# 29              P                     8                    6  ...           2
# 30              P                     7                    8  ...           1
# 31              C                     8                    8  ...           1
#
#                  teamName  teamCommonName  teamAbbrev  \
# 0        Florida Panthers        Panthers         FLA
# 1       Vancouver Canucks         Canucks         VAN
# 2           Boston Bruins          Bruins         BOS
# 3            Dallas Stars           Stars         DAL
# 4        New York Rangers         Rangers         NYR
# 5           Winnipeg Jets            Jets         WPG
# 6      Colorado Avalanche       Avalanche         COL
# 7     Carolina Hurricanes      Hurricanes         CAR
# 8     Toronto Maple Leafs     Maple Leafs         TOR
# 9         Edmonton Oilers          Oilers         EDM
# 10    Nashville Predators       Predators         NSH
# 11      Los Angeles Kings           Kings         LAK
# 12   Vegas Golden Knights  Golden Knights         VGK
# 13    Tampa Bay Lightning       Lightning         TBL
# 14    Philadelphia Flyers          Flyers         PHI
# 15      Detroit Red Wings       Red Wings         DET
# 16     New York Islanders       Islanders         NYI
# 17    Washington Capitals        Capitals         WSH
# 18        St. Louis Blues           Blues         STL
# 19         Minnesota Wild            Wild         MIN
# 20         Seattle Kraken          Kraken         SEA
# 21         Calgary Flames          Flames         CGY
# 22      New Jersey Devils          Devils         NJD
# 23         Buffalo Sabres          Sabres         BUF
# 24    Pittsburgh Penguins        Penguins         PIT
# 25     Montréal Canadiens       Canadiens         MTL
# 26        Arizona Coyotes         Coyotes         ARI
# 27        Ottawa Senators        Senators         OTT
# 28  Columbus Blue Jackets    Blue Jackets         CBJ
# 29          Anaheim Ducks           Ducks         ANA
# 30        San Jose Sharks          Sharks         SJS
# 31     Chicago Blackhawks      Blackhawks         CHI
#
#                                              teamLogo  ties  waiversSequence  \
# 0   https://assets.nhle.com/logos/nhl/svg/FLA_ligh...     0               32
# 1   https://assets.nhle.com/logos/nhl/svg/VAN_ligh...     0               31
# 2   https://assets.nhle.com/logos/nhl/svg/BOS_ligh...     0               28
# 3   https://assets.nhle.com/logos/nhl/svg/DAL_ligh...     0               27
# 4   https://assets.nhle.com/logos/nhl/svg/NYR_ligh...     0               30
# 5   https://assets.nhle.com/logos/nhl/svg/WPG_ligh...     0               29
# 6   https://assets.nhle.com/logos/nhl/svg/COL_ligh...     0               25
# 7   https://assets.nhle.com/logos/nhl/svg/CAR_ligh...     0               26
# 8   https://assets.nhle.com/logos/nhl/svg/TOR_ligh...     0               23
# 9   https://assets.nhle.com/logos/nhl/svg/EDM_ligh...     0               24
# 10  https://assets.nhle.com/logos/nhl/svg/NSH_ligh...     0               21
# 11  https://assets.nhle.com/logos/nhl/svg/LAK_ligh...     0               22
# 12  https://assets.nhle.com/logos/nhl/svg/VGK_ligh...     0               20
# 13  https://assets.nhle.com/logos/nhl/svg/TBL_ligh...     0               19
# 14  https://assets.nhle.com/logos/nhl/svg/PHI_ligh...     0               18
# 15  https://assets.nhle.com/logos/nhl/svg/DET_ligh...     0               17
# 16  https://assets.nhle.com/logos/nhl/svg/NYI_ligh...     0               16
# 17  https://assets.nhle.com/logos/nhl/svg/WSH_ligh...     0               15
# 18  https://assets.nhle.com/logos/nhl/svg/STL_ligh...     0               13
# 19  https://assets.nhle.com/logos/nhl/svg/MIN_ligh...     0               12
# 20  https://assets.nhle.com/logos/nhl/svg/SEA_ligh...     0               14
# 21  https://assets.nhle.com/logos/nhl/svg/CGY_ligh...     0               11
# 22  https://assets.nhle.com/logos/nhl/svg/NJD_ligh...     0                9
# 23  https://assets.nhle.com/logos/nhl/svg/BUF_ligh...     0                8
# 24  https://assets.nhle.com/logos/nhl/svg/PIT_ligh...     0               10
# 25  https://assets.nhle.com/logos/nhl/svg/MTL_ligh...     0                7
# 26  https://assets.nhle.com/logos/nhl/svg/ARI_ligh...     0                6
# 27  https://assets.nhle.com/logos/nhl/svg/OTT_ligh...     0                5
# 28  https://assets.nhle.com/logos/nhl/svg/CBJ_ligh...     0                4
# 29  https://assets.nhle.com/logos/nhl/svg/ANA_ligh...     0                3
# 30  https://assets.nhle.com/logos/nhl/svg/SJS_ligh...     0                2
# 31  https://assets.nhle.com/logos/nhl/svg/CHI_ligh...     0                1
#
#     wildcardSequence   winPctg  wins
# 0                  0  0.676923    44
# 1                  0  0.636364    42
# 2                  0  0.567164    38
# 3                  0  0.606061    40
# 4                  0  0.656250    42
# 5                  0  0.640625    41
# 6                  0  0.615385    40
# 7                  0  0.609375    39
# 8                  0  0.578125    37
# 9                  0  0.619048    39
# 10                 1  0.560606    37
# 11                 0  0.515625    33
# 12                 2  0.531250    34
# 13                 1  0.523077    34
# 14                 0  0.507692    33
# 15                 2  0.515625    33
# 16                 3  0.453125    29
# 17                 4  0.476190    30
# 18                 3  0.507692    33
# 19                 4  0.476923    31
# 20                 5  0.444444    28
# 21                 6  0.484375    31
# 22                 5  0.476923    31
# 23                 6  0.461538    30
# 24                 7  0.444444    28
# 25                 8  0.375000    24
# 26                 7  0.400000    26
# 27                 9  0.403226    25
# 28                10  0.343750    22
# 29                 8  0.359375    23
# 30                 9  0.253968    16
# 31                10  0.261538    17
#
# [32 rows x 80 columns]
# Number of columns: 80

# %%
import requests
import pandas as pd
# API call to retrieve current top goal scorer data
url = "https://api-web.nhle.com/v1/roster/TOR/current"
params = {
    "categories": "roster",
    "limit": 45
}
response = requests.get(url, params=params)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Extract the JSON data from the response
    data = response.json()
    
    # Create an empty list to store column names
    player_data_col_names= []

    # Get the names of all the columns
    for col in data['forwards'][0]: 
        player_data_col_names.append(col)

    # Df to show all win stats
    roster_df = pd.DataFrame(columns=player_data_col_names)
    
    #Loop through items in dict, retrieve data by keys "cat"
    # Add forwards to df
    for player_stat in data['forwards']:
        player = {}
        for cat in player_data_col_names:
            player[cat] = get_first_value(player_stat.get(cat, None))
        
        roster_df.loc[len(roster_df)] = player

    # Add defensemen to df
    for player_stat in data['defensemen']:
        player = {}
        for cat in player_data_col_names:
            player[cat] = get_first_value(player_stat.get(cat, None))
            
        roster_df.loc[len(roster_df)] = player

    # Add goalies to df
    for player_stat in data['goalies']:
        player = {}
        for cat in player_data_col_names:
            player[cat] = get_first_value(player_stat.get(cat, None))
            
        roster_df.loc[len(roster_df)] = player

    print(roster_df)

    # Check df shape
    num_columns = roster_df.shape[1]
    print("Number of columns:", num_columns)
    print("Number of rows:", len(roster_df))

else:
    print("Failed to fetch data from the API:", response.status_code)
# Out:
#          id                                           headshot firstName  \
# 0   8477479  https://assets.nhle.com/mugs/nhl/20232024/TOR/...     Tyler
# 1   8480980  https://assets.nhle.com/mugs/nhl/20232024/TOR/...    Connor
# 2   8477503  https://assets.nhle.com/mugs/nhl/20232024/TOR/...       Max
# 3   8479393  https://assets.nhle.com/mugs/nhl/20232024/TOR/...      Noah
# 4   8480995  https://assets.nhle.com/mugs/nhl/20232024/TOR/...    Pontus
# 5   8475714  https://assets.nhle.com/mugs/nhl/20232024/TOR/...     Calle
# 6   8480144  https://assets.nhle.com/mugs/nhl/20232024/TOR/...     David
# 7   8482720  https://assets.nhle.com/mugs/nhl/20232024/TOR/...   Matthew
# 8   8478483  https://assets.nhle.com/mugs/nhl/20232024/TOR/...     Mitch
# 9   8479318  https://assets.nhle.com/mugs/nhl/20232024/TOR/...    Auston
# 10  8482259  https://assets.nhle.com/mugs/nhl/20232024/TOR/...     Bobby
# 11  8477939  https://assets.nhle.com/mugs/nhl/20232024/TOR/...   William
# 12  8471817  https://assets.nhle.com/mugs/nhl/20232024/TOR/...      Ryan
# 13  8481582  https://assets.nhle.com/mugs/nhl/20232024/TOR/...  Nicholas
# 14  8475166  https://assets.nhle.com/mugs/nhl/20232024/TOR/...      John
# 15  8481122  https://assets.nhle.com/mugs/nhl/20232024/TOR/...     Simon
# 16  8474673  https://assets.nhle.com/mugs/nhl/20232024/TOR/...        TJ
# 17  8476441  https://assets.nhle.com/mugs/nhl/20232024/TOR/...      Joel
# 18  8470966  https://assets.nhle.com/mugs/nhl/20232024/TOR/...      Mark
# 19  8475906  https://assets.nhle.com/mugs/nhl/20232024/TOR/...      John
# 20  8480043  https://assets.nhle.com/mugs/nhl/20232024/TOR/...   Timothy
# 21  8480950  https://assets.nhle.com/mugs/nhl/20232024/TOR/...      Ilya
# 22  8476931  https://assets.nhle.com/mugs/nhl/20232024/TOR/...      Jake
# 23  8474162  https://assets.nhle.com/mugs/nhl/20232024/TOR/...      Jake
# 24  8476853  https://assets.nhle.com/mugs/nhl/20232024/TOR/...    Morgan
# 25  8479982  https://assets.nhle.com/mugs/nhl/20232024/TOR/...     Conor
# 26  8474889  https://assets.nhle.com/mugs/nhl/20232024/TOR/...    Martin
# 27  8478492  https://assets.nhle.com/mugs/nhl/20232024/TOR/...      Ilya
# 28  8479361  https://assets.nhle.com/mugs/nhl/20232024/TOR/...    Joseph
#
#       lastName  sweaterNumber positionCode shootsCatches  heightInInches  \
# 0     Bertuzzi             59            L             L              74
# 1        Dewar             24            C             L              70
# 2         Domi             11            C             L              70
# 3       Gregor             18            C             L              72
# 4     Holmberg             29            R             L              72
# 5     Jarnkrok             19            C             R              72
# 6        Kampf             64            C             L              74
# 7        Knies             23            L             L              75
# 8       Marner             16            R             R              72
# 9     Matthews             34            C             L              75
# 10      McMann             74            C             L              74
# 11    Nylander             88            R             R              72
# 12      Reaves             75            R             R              74
# 13   Robertson             89            L             L              69
# 14     Tavares             91            C             L              73
# 15      Benoit              2            D             L              76
# 16      Brodie             78            D             L              74
# 17   Edmundson             20            D             L              77
# 18    Giordano             55            D             L              72
# 19   Klingberg              3            D             R              74
# 20   Liljegren             37            D             R              73
# 21  Lyubushkin             46            D             R              74
# 22      McCabe             22            D             L              73
# 23      Muzzin              8            D             L              75
# 24      Rielly             44            D             L              73
# 25     Timmins             25            D             R              74
# 26       Jones             31            G             L              77
# 27    Samsonov             35            G             L              75
# 28        Woll             60            G             L              75
#
#     weightInPounds  heightInCentimeters  weightInKilograms   birthDate  \
# 0              200                  188                 91  1995-02-24
# 1              183                  178                 83  1999-06-26
# 2              208                  178                 94  1995-03-02
# 3              192                  183                 87  1998-07-28
# 4              188                  183                 85  1999-03-09
# 5              190                  183                 86  1991-09-25
# 6              190                  188                 86  1995-01-12
# 7              217                  191                 98  2002-10-17
# 8              180                  183                 82  1997-05-05
# 9              215                  191                 98  1997-09-17
# 10             210                  188                 95  1996-06-15
# 11             202                  183                 92  1996-05-01
# 12             226                  188                103  1987-01-20
# 13             178                  175                 81  2001-09-11
# 14             211                  185                 96  1990-09-20
# 15             205                  193                 93  1998-09-19
# 16             187                  188                 85  1990-06-07
# 17             221                  196                100  1993-06-28
# 18             202                  183                 92  1983-10-03
# 19             185                  188                 84  1992-08-14
# 20             190                  185                 86  1999-04-30
# 21             200                  188                 91  1994-04-06
# 22             211                  185                 96  1993-10-12
# 23             227                  191                103  1989-02-21
# 24             225                  185                102  1994-03-09
# 25             206                  188                 93  1998-09-18
# 26             203                  196                 92  1990-01-10
# 27             217                  191                 98  1997-02-22
# 28             202                  191                 92  1998-07-12
#
#            birthCity birthCountry birthStateProvince
# 0            Sudbury          CAN            Ontario
# 1            The Pas          CAN           Manitoba
# 2           Winnipeg          CAN           Manitoba
# 3           Beaumont          CAN            Alberta
# 4           Vasteras          SWE               None
# 5              Gavle          SWE               None
# 6           Chomutov          CZE               None
# 7            Phoenix          USA            Arizona
# 8            Markham          CAN            Ontario
# 9          San Ramon          USA         California
# 10        Wainwright          CAN            Alberta
# 11           Calgary          CAN            Alberta
# 12          Winnipeg          CAN           Manitoba
# 13          Pasadena          USA         California
# 14       Mississauga          CAN            Ontario
# 15             Laval          CAN             Quebec
# 16           Chatham          CAN            Ontario
# 17           Brandon          CAN           Manitoba
# 18           Toronto          CAN            Ontario
# 19        Gothenburg          SWE               None
# 20      Kristianstad          SWE               None
# 21            Moscow          RUS               None
# 22        Eau Claire          USA          Wisconsin
# 23         Woodstock          CAN            Ontario
# 24         Vancouver          CAN   British Columbia
# 25    St. Catharines          CAN            Ontario
# 26   North Vancouver          CAN   British Columbia
# 27      Magnitogorsk          RUS               None
# 28  Dardenne Prairie          USA           Missouri
# Number of columns: 15
# Number of rows: 29
